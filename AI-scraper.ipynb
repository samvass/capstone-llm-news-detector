# %%
import requests
from bs4 import BeautifulSoup as bs
import unicodedata
import pandas as pd
import os
import re

# %%
import unicodedata

def sanitize_filename(filename):
    # Replace non-English characters with their English letter equivalents
    normalized_filename = ''.join(c for c in unicodedata.normalize('NFD', filename) if unicodedata.category(c) != 'Mn')
    # Replace invalid characters with underscores
    return re.sub(r'[<>:"/\\|?*]', '_', normalized_filename)

# %%
def parse_news_article(link):
    response = requests.get(link)
    soup = bs(response.content, features='html.parser')
    
    # get title
    title = soup.find('h1', class_="fusion-title-heading title-heading-left").text
    
    # get text content
    p_section = soup.find('div', class_="fusion-content-tb fusion-content-tb-1")
    p = p_section.find_all('p') if p_section else []
    p = [x.text for x in p]
    
    # image
    img_url = soup.find('img', alt=title)['src']
    img_response = requests.get(img_url)

    os.makedirs('images', exist_ok=True)
    
    # title_fixed = title.replace(" ", "_").replace("/", "_").replace(";", "").replace("'", "").replace(",", "").replace("“", "").replace("”", "").replace(":", "").replace("’", "").replace("-", "")
    sanitize_img_filename = sanitize_filename(title)
    img_filename = f"images/{sanitize_img_filename}.jpg"
    
    # Save image to the file
    if img_response.status_code == 200:
        with open(img_filename, 'wb') as img_file:
            # print(img_filename)
            img_file.write(img_response.content)
    else:
        print(f"Failed to fetch image from {img_url}. Status code: {img_response.status_code}")

        
    img_filename = img_filename.split('/')[1]
    
    # return parsed article
    return title, p, img_filename

# %%
def get_articles_links(homepage_url, news_links):
    response = requests.get(homepage_url)
    soup = bs(response.content, features='html.parser')

    # parse through main news page
    news_a_tags = soup.find_all('a', class_="awb-custom-text-color awb-custom-text-hover-color")

    for link in news_a_tags:
        news_links.append(link['href'])

# %%
news_links = []

# loops through 5 pages of homepage and stores the link from every news article
for page_num in range(1,3):
    base_url = 'https://newsgpt.ai/ai-news/page/'
    updated_url = base_url + str(page_num) 
    get_articles_links(updated_url, news_links)

# %%
titles = []
paragraphs_df = []
images = []

print(len(news_links))
os.makedirs('AI_articles', exist_ok=True)

hello = 1
test_set = set()
for link in news_links:
    t,p,i = parse_news_article(link)
    sanitized_title = sanitize_filename(t)

    titles.append(sanitized_title)

    if (test_set.__contains__(sanitized_title)):
        print("ALREADY DONE " + str(hello))
        hello += 1
    

    test_set.add(sanitized_title)
    p_single_string = ' '.join(p)
    paragraphs_df.append(p_single_string)
    # paragraphs.extend(p)
    images.append(i)

    # # Concatenate all paragraphs into a single string
    # full_text = '\n\n'.join(p)

    # # Save the concatenated text into a single file in 'AI_texts' folder
    # file_path = os.path.join("./AI_articles", f"{sanitized_title}.txt")
    # with open(file_path, 'w', encoding='utf-8') as file:
    #     file.write(full_text)
# Out:
# 60

# %%
# create pd df to store the data
df = pd.DataFrame({
    'Title': titles,
    'Paragraph': paragraphs_df,
    'Image': images
})

# %%
df
# Out:
#                                                 Title  \
# 0   Tesla Berlin Factory Resumes Production After ...
# 1   Tragic Death of Itai Chen, U.S.-Israeli Hostag...
# 2   Felipe Massa Sues Bernie Ecclestone and FIA fo...
# 3   Tragedy Strikes Iditarod_ Two Dogs Die in Grue...
# 4   England Faces Measles Surge_ Over 1 Million Un...
# 5   Necture Secures $7M Series A Funding for Fleet...
# 6   Doriane Pin’s Exceptional Talent Shines in F1 ...
# 2   Former Ferrari driver, Felipe Massa, has initi...
# 3   Over the weekend, the annual Iditarod sled dog...
# 4   In the wake of a significant increase in measl...
# 5   Austrian start-up Necture, which has developed...
# 6   Doriane Pin, a rising star in the world of For...
# 7   VAST Data has unveiled a novel AI cloud archit...
# 8   The upcoming iPad Pro, particularly the 11-inc...
# 9   The Transport Accident Investigation Commissio...
# 10  President Biden’s recent State of the Union ad...
# 11  Renowned singer Celine Dion recently made a ra...
# 12  Several Taco Bell outlets in Oakland have shut...
# 13  Pro-Ukrainian Russian fighters have reportedly...
# 14  A Kansas judge has ruled that the state’s refu...
# 15  Eric Carmen, the renowned frontman of the Rasp...
# 16  Michael Cargill, a representative of a gun rig...
# 17  Massachusetts Governor Maura Healey is set to ...
# 18  NHS workers who experience a miscarriage befor...
# 19  Qualcomm has recently made several significant...
# 20  In a bid to combat air pollution and reduce co...
# 21  Donald Trump, the former U.S. president, is pr...
# 22  The internet is buzzing with a new trend of us...
# 23  Nvidia, the tech giant known for its artificia...
# 24  A “green comet” known as 12P/Pons–Brooks, last...
# 25  Former Deputy Assistant Attorney General John ...
# 26  Joe Biden has secured the Democratic nominatio...
# 27  In response to escalating civil unrest in Hait...
# 28  A recent data breach has impacted over 15,000 ...
# 29  A dramatic explosion occurred seconds after th...
# 30  The US is set to provide approximately $300m i...
# 31  Public libraries across the United States are ...
# 32  Rep. Nancy Mace, a representative from South C...
# 33  In a recent controversy, Tiffany Henyard, the ...
# 34  In a significant development, a suspect, Muham...
# 35  The NFL free agency period has kicked off with...
# 36  Former President Donald Trump has pledged to r...
# 37  A deceptive online scam has been targeting sup...
# 38  The field of contraception, which has seen lim...
# 39  The UK government is potentially moving toward...
# 40  LG Electronics, the South Korean electronics g...
# 41  FPV drones, or kamikaze racing quadcopters, ha...
# 42  Inflation in the US has been a hot topic, with...
# 43  The future of YouTube might be on the brink of...
# 44  In the wake of financial turbulence, Silicon V...
# 45  Former President Donald Trump has been ordered...
# 46  John Barnett, a former Boeing employee and whi...
# 47  In a surprising turn of events, world No. 123 ...
# 48  In a shocking incident, a LATAM Airlines Boein...
# 49  AI-manipulated video clips of Adolf Hitler’s 1...
# 50  In a surprising turn of events, former US Pres...
# 51  British travelers to Gibraltar may soon face S...
# 52  In a surprising turn of events, world number o...
# 53  Despite high hopes following their unexpected ...
# 54  The atmosphere at the Arsenal training ground ...
# 55  Airbnb is set to prohibit hosts from using ind...
# 56  AI startup Nanonets has secured $29 million in...
# 57  In 2023, Apple’s smartwatch took significant s...
# 58  Andrew and Tristan Tate, known for their contr...
# 59  The 2024 Oscars ceremony had its fair share of...
#
#                                                 Image
# 0   Tesla Berlin Factory Resumes Production After ...
# 1   Tragic Death of Itai Chen, U.S.-Israeli Hostag...
# 2   Felipe Massa Sues Bernie Ecclestone and FIA fo...
# 3   Tragedy Strikes Iditarod_ Two Dogs Die in Grue...
# 4   England Faces Measles Surge_ Over 1 Million Un...
# 5   Necture Secures $7M Series A Funding for Fleet...
# 6   Doriane Pin’s Exceptional Talent Shines in F1 ...
# 7   VAST Data Unveils Revolutionary AI Cloud Archi...
# 8   iPad Pro 11-Inch Model Faces Supply Constraint...
# 9   LATAM Airlines Boeing 787-9 Dreamliner Inciden...
# 10  Biden’s Gun Control Agenda Sparks Controversy ...
# 11  Celine Dion’s Rare Appearance at Vegas Golden ...
# 12  Taco Bell Dining Rooms Close in Oakland Amid C...
# 13  Pro-Ukrainian Russian Fighters Launch Cross-Bo...
# 14  Kansas Court Upholds State’s Refusal to Alter ...
# 15  Legendary Musician Eric Carmen Passes Away at ...
# 16  Supreme Court to Rule on Illinois Gun Ban in C...
# 17  Massachusetts Governor Maura Healey to Grant P...
# 18  NHS Extends Paid Leave for Miscarriage and Bab...
# 19  Qualcomm’s AI Revolution_ Powering Next-Genera...
# 20  Eco-Friendly Compressed Earth Bricks_ A Soluti...
# 21  Donald Trump’s Advice-of-Counsel Defense in Cr...
# 22  AI-Generated Children’s Content on YouTube_ Fi...
# 23  Nvidia Stock Surges Despite Recent Dip, Invest...
# 24  Green Comet 12P_Pons–Brooks Returns to Solar S...
# 25  Congressional Hearing Highlights Biden’s Misha...
# 26  Biden Secures Democratic Nomination, Trump Nea...
# 27  U.S. Evacuates Embassy Personnel as Haiti’s Cr...
# 28  Roku Data Breach Impacts 15,000 Users, Comprom...
# 29  Japanese Rocket Explosion Dampens Space One’s ...
# 30  US Provides $300m Military Aid to Ukraine Amid...
# 31  Soaring Costs of Ebooks and Audiobooks Challen...
# 32  ABC News Anchor George Stephanopoulos Faces Ca...
# 33  Mayor Tiffany Henyard Accused of Taxpayer Misu...
# 34  Albuquerque Muslim Killings_ Afghan Refugee Ch...
# 35  NFL Free Agency Frenzy_ Kirk Cousins, Saquon B...
# 36  Trump Pledges to Release “Wrongfully Imprisone...
# 37  Deepfake Scam Targets Trump Supporters, Impers...
# 38  Contraception Innovation Resurges_ New Methods...
# 39  UK Faces Potential Ransomware Crisis as Govern...
# 40  LG Invests $60 Million in Bear Robotics, Bolst...
# 41  FPV Drones Revolutionize Warfare with Airburst...
# 42  Inflation Surges_ Rent Costs Skyrocket, Dampen...
# 43  The Future of YouTube_ Mass Exodus of Creators...
# 44  Silicon Valley Veterans Offer Personal Loans t...
# 45  Trump Ordered to Pay $450 Million in Civil Fra...
# 46  Boeing Whistleblower John Barnett Found Dead i...
# 47  Luca Nardi Stuns Novak Djokovic in BNP Paribas...
# 48  LATAM Airlines Flight Drops Mid-Air, Injuring ...
# 49  AI-Manipulated Hitler Speech Videos Raise Conc...
# 50  Trump Reverses Stance on TikTok, Expresses Con...
# 51  Gibraltar Airport to Implement Schengen Checks...
# 52  Novak Djokovic Stuns in Indian Wells Defeat to...
# 53  England Crushed in Dharamsala, Series Loss Loo...
# 54  Arsenal’s Electric Atmosphere_ Arteta Calls fo...
# 55  Airbnb Bans Indoor Security Cameras, Prioritiz...
# 56  Nanonets Secures $29M to Revolutionize Unstruc...
# 57  Apple Watch X_ Rumors, Features, and Future of...
# 58  Tate Brothers Detained in Romania on Sexual Cr...
# 59  Messi’s Clapping Moment Steals the Show at the...

# %%
# Save to CSV
df.to_csv('AI_data.csv', index=False)

# %%
def count_items_in_folder(folder_path):
    count = 0
    for _, _, files in os.walk(folder_path):
        count += len(files)
    return count

folder_path = "./AI_articles"
num_items = count_items_in_folder(folder_path)
print(num_items)
# Out:
# 0
